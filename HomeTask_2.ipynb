# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
stud=pd.read_csv('/content/student performance predictions.csv')

# %%
stud.head()
# Out:
#    StudentID     Name  Gender  AttendanceRate  StudyHoursPerWeek  \
# 0          1     John    Male              85                 15
# 1          2    Sarah  Female              90                 20
# 2          3     Alex    Male              78                 10
# 3          4  Michael    Male              92                 25
# 4          5     Emma  Female              88                 18
#
#    PreviousGrade  ExtracurricularActivities ParentalSupport  FinalGrade
# 0             78                          1            High          80
# 1             85                          2          Medium          87
# 2             65                          0             Low          68
# 3             90                          3            High          92
# 4             82                          2          Medium          85

# %%
LR=LinearRegression()

# %%
stud.isnull().sum()
# Out:
# StudentID                    0
# Name                         0
# Gender                       0
# AttendanceRate               0
# StudyHoursPerWeek            0
# PreviousGrade                0
# ExtracurricularActivities    0
# ParentalSupport              0
# FinalGrade                   0
# dtype: int64

# %%
stud.dropna(inplace=True)

# %%
stud.isnull().sum()
# Out:
# StudentID                    0
# Name                         0
# Gender                       0
# AttendanceRate               0
# StudyHoursPerWeek            0
# PreviousGrade                0
# ExtracurricularActivities    0
# ParentalSupport              0
# FinalGrade                   0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
x=LabelEncoder()
y=LabelEncoder()
stud['Gen_new']=x.fit_transform(stud['Gender'])
stud['PreviousGrade']=y.fit_transform(stud['PreviousGrade'])

# %%
stud = pd.get_dummies(stud, columns=['ParentalSupport'], drop_first=True)
parental_support_cols = [col for col in stud.columns if col.startswith('ParentalSupport_')]

a = stud[parental_support_cols]
b=stud[['FinalGrade']]

# %%
LR.fit(a,b)
# Out:
# LinearRegression()

# %%
LR.predict([[1,0,0]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[82.75]])
